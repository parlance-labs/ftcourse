# %% [markdown]
# # The Prompt
#
# In the beginning, you should prototype with a powerful model (like GPT-4, Mistral Large, Llama 70b etc) to see what is possible.
#
# ## The original Honeycomb prompt
#
# - `COLUMNS` are retrieved via RAG at the time the model is called.
# - They used OpenAI with a completion-style API (didn't need to chat)
#
# ```
# NLQ:{{question}}
# EXISTING QUERY:{
# ```

# %%
# !cat sample_data/original_prompt.txt
# Out:
# Honeycomb AI suggests queries based on user input.
#
# ...

# %% [markdown]
# ## They Launched with just the prompt
#
# https://www.honeycomb.io/blog/introducing-query-assistant
#
# - We built some minimal evals first.
# - Not everyone can just ship that fast, they went straight to A/B testing.
# - Goal: "to encourage more users to write queries". (no quality goal at the outset).
